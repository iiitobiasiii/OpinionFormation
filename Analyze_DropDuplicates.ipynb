# %% [markdown]
# Zieht sich die Parameterwerte aller Durchläufe in einen pandas dataframe

# %%
import pandas as pd
import glob
import numpy as np

#Dataset with or without manipulation?
manip = 1

path =r'./data/newdata' # use your path
allFiles = glob.glob(path + "/*.txt")
frame = pd.DataFrame()

#will be converted to dataframe
list_ = []

#dict of style index in frame : (filename, index in file)
findfile = {}

#index for rows in frame
curr_row = 0
for file_ in allFiles:
    orig_ind = 0
    n = 3 + manip  #Add number of lines that will appear if manipulation is on!
    num_lines = sum(1 for l in open(file_))
    skip_idx = [x for x in range(1, num_lines) if x % n != 0]
    df = pd.read_csv(file_,index_col=None, skiprows=skip_idx, header = None)
    list_.append(df)
    for i in range(curr_row, curr_row+len(df.index)):
        findfile[i] = (file_, orig_ind)
        orig_ind += 1
    curr_row +=len(df.index)
frame = pd.concat(list_, ignore_index=True)
with pd.option_context('display.max_rows', 100, 'display.max_columns', 20):
    display(frame)
# Out:
#                  0             1            2                    3  \
# 0      Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 184000
# 1      Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 208000
# 2      Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 200000
# 3      Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 200000
# 4      Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 176000
# 5      Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 216000
# 6      Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 200000
# 7      Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 224000
# 8      Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 176000
# 9      Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 192000
# 10     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 192000
# 11     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 192000
# 12     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 184000
# 13     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 192000
# 14     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 192000
# 15     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 184000
# 16     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 184000
# 17     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 192000
# 18     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 200000
# 19     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 176000
# 20     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 224000
# 21     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 208000
# 22     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 208000
# 23     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 200000
# 24     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 248000
# 25     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 192000
# 26     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 176000
# 27     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 216000
# 28     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 192000
# 29     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 184000
# 30     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 200000
# 31     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 192000
# 32     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 176000
# 33     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 192000
# 34     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 232000
# 35     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 208000
# 36     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 168000
# 37     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 192000
# 38     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 184000
# 39     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 200000
# 40     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 208000
# 41     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 176000
# 42     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 232000
# 43     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 200000
# 44     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 200000
# 45     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 184000
# 46     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 192000
# 47     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 192000
# 48     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 208000
# 49     Nodes: 1600   Edges: 3200   phi: 0.120   Iterations: 184000
# ...            ...           ...          ...                  ...
# 49950  Nodes: 1600   Edges: 3200   phi: 1.000   Iterations: 360000
# 49951  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 16000
# 49952  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 16000
# 49953  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 16000
# 49954  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 16000
# 49955  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 16000
# 49956  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 16000
# 49957  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 16000
# 49958  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 16000
# 49959  Nodes: 1600   Edges: 3200   phi: 1.000   Iterations: 256000
# 49960  Nodes: 1600   Edges: 3200   phi: 1.000   Iterations: 168000
# 49961  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 88000
# 49962  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 88000
# 49963  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 88000
# 49964  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 16000
# 49965  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 16000
# 49966  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 16000
# 49967  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 16000
# 49968  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 16000
# 49969  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 24000
# 49970  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 24000
# 49971  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 24000
# 49972  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 24000
# 49973  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 24000
# 49974  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 24000
# 49975  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 56000
# 49976  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 56000
# 49977  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 56000
# 49978  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 56000
# 49979  Nodes: 1600   Edges: 3200   phi: 1.000   Iterations: 320000
# 49980  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 96000
# 49981  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 16000
# 49982  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 16000
# 49983  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 16000
# 49984  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 16000
# 49985  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 16000
# 49986  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 96000
# 49987  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 96000
# 49988  Nodes: 1600   Edges: 3200   phi: 1.000   Iterations: 104000
# 49989  Nodes: 1600   Edges: 3200   phi: 1.000   Iterations: 104000
# 49990  Nodes: 1600   Edges: 3200   phi: 1.000   Iterations: 920000
# 49991  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 16000
# 49992  Nodes: 1600   Edges: 3200   phi: 1.000   Iterations: 752000
# 49993  Nodes: 1600   Edges: 3200   phi: 1.000   Iterations: 168000
# 49994  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 48000
# 49995  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 48000
# 49996  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 48000
# 49997  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 48000
# 49998  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 16000
# 49999  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 16000
#
#                      4
# 0       Influencer: 2
# 1       Influencer: 2
# 2       Influencer: 2
# 3       Influencer: 2
# 4       Influencer: 2
# 5       Influencer: 2
# 6       Influencer: 2
# 7       Influencer: 2
# 8       Influencer: 2
# 9       Influencer: 2
# 10      Influencer: 2
# 11      Influencer: 2
# 12      Influencer: 2
# 13      Influencer: 2
# 14      Influencer: 2
# 15      Influencer: 2
# 16      Influencer: 2
# 17      Influencer: 2
# 18      Influencer: 2
# 19      Influencer: 2
# 20      Influencer: 2
# 21      Influencer: 2
# 22      Influencer: 2
# 23      Influencer: 2
# 24      Influencer: 2
# 25      Influencer: 2
# 26      Influencer: 2
# 27      Influencer: 2
# 28      Influencer: 2
# 29      Influencer: 2
# 30      Influencer: 2
# 31      Influencer: 2
# 32      Influencer: 2
# 33      Influencer: 2
# 34      Influencer: 2
# 35      Influencer: 2
# 36      Influencer: 2
# 37      Influencer: 2
# 38      Influencer: 2
# 39      Influencer: 2
# 40      Influencer: 2
# 41      Influencer: 2
# 42      Influencer: 2
# 43      Influencer: 2
# 44      Influencer: 2
# 45      Influencer: 2
# 46      Influencer: 2
# 47      Influencer: 2
# 48      Influencer: 2
# 49      Influencer: 2
# ...                ...
# 49950   Influencer: 8
# 49951   Influencer: 8
# 49952   Influencer: 8
# 49953   Influencer: 8
# 49954   Influencer: 8
# 49955   Influencer: 8
# 49956   Influencer: 8
# 49957   Influencer: 8
# 49958   Influencer: 8
# 49959   Influencer: 8
# 49960   Influencer: 8
# 49961   Influencer: 8
# 49962   Influencer: 8
# 49963   Influencer: 8
# 49964   Influencer: 8
# 49965   Influencer: 8
# 49966   Influencer: 8
# 49967   Influencer: 8
# 49968   Influencer: 8
# 49969   Influencer: 8
# 49970   Influencer: 8
# 49971   Influencer: 8
# 49972   Influencer: 8
# 49973   Influencer: 8
# 49974   Influencer: 8
# 49975   Influencer: 8
# 49976   Influencer: 8
# 49977   Influencer: 8
# 49978   Influencer: 8
# 49979   Influencer: 8
# 49980   Influencer: 8
# 49981   Influencer: 8
# 49982   Influencer: 8
# 49983   Influencer: 8
# 49984   Influencer: 8
# 49985   Influencer: 8
# 49986   Influencer: 8
# 49987   Influencer: 8
# 49988   Influencer: 8
# 49989   Influencer: 8
# 49990   Influencer: 8
# 49991   Influencer: 8
# 49992   Influencer: 8
# 49993   Influencer: 8
# 49994   Influencer: 8
# 49995   Influencer: 8
# 49996   Influencer: 8
# 49997   Influencer: 8
# 49998   Influencer: 8
# 49999   Influencer: 8
#
# [50000 rows x 5 columns]

# %%
frame.drop_duplicates(subset=[0,1,2,4], inplace=True)
frame = frame.reset_index(drop=True)
with pd.option_context('display.max_rows', 100, 'display.max_columns', 20):
    display(frame)
# Out:
#               0             1            2                     3  \
# 0   Nodes: 1600   Edges: 3200   phi: 0.120    Iterations: 184000
# 1   Nodes: 1600   Edges: 3200   phi: 0.120    Iterations: 208000
# 2   Nodes: 1600   Edges: 3200   phi: 0.670     Iterations: 32000
# 3   Nodes: 1600   Edges: 3200   phi: 0.670     Iterations: 32000
# 4   Nodes: 1600   Edges: 3200   phi: 0.890     Iterations: 32000
# 5   Nodes: 1600   Edges: 3200   phi: 0.890     Iterations: 80000
# 6   Nodes: 1600   Edges: 3200   phi: 0.010    Iterations: 120000
# 7   Nodes: 1600   Edges: 3200   phi: 0.120    Iterations: 200000
# 8   Nodes: 1600   Edges: 3200   phi: 0.670     Iterations: 32000
# 9   Nodes: 1600   Edges: 3200   phi: 0.670     Iterations: 32000
# 10  Nodes: 1600   Edges: 3200   phi: 0.890     Iterations: 24000
# 11  Nodes: 1600   Edges: 3200   phi: 1.000     Iterations: 32000
# 12  Nodes: 1600   Edges: 3200   phi: 0.230     Iterations: 88000
# 13  Nodes: 1600   Edges: 3200   phi: 0.230     Iterations: 88000
# 14  Nodes: 1600   Edges: 3200   phi: 0.450     Iterations: 40000
# 15  Nodes: 1600   Edges: 3200   phi: 0.450     Iterations: 40000
# 16  Nodes: 1600   Edges: 3200   phi: 0.450     Iterations: 48000
# 17  Nodes: 1600   Edges: 3200   phi: 0.560     Iterations: 32000
# 18  Nodes: 1600   Edges: 3200   phi: 0.670     Iterations: 32000
# 19  Nodes: 1600   Edges: 3200   phi: 0.780     Iterations: 40000
# 20  Nodes: 1600   Edges: 3200   phi: 1.000     Iterations: 16000
# 21  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 168000
# 22  Nodes: 1600   Edges: 3200   phi: 0.010     Iterations: 96000
# 23  Nodes: 1600   Edges: 3200   phi: 0.010   Iterations: 1352000
# 24  Nodes: 1600   Edges: 3200   phi: 0.010    Iterations: 152000
# 25  Nodes: 1600   Edges: 3200   phi: 0.010    Iterations: 120000
# 26  Nodes: 1600   Edges: 3200   phi: 0.230     Iterations: 80000
# 27  Nodes: 1600   Edges: 3200   phi: 0.230     Iterations: 88000
# 28  Nodes: 1600   Edges: 3200   phi: 0.340     Iterations: 56000
# 29  Nodes: 1600   Edges: 3200   phi: 0.340     Iterations: 56000
# 30  Nodes: 1600   Edges: 3200   phi: 0.560     Iterations: 32000
# 31  Nodes: 1600   Edges: 3200   phi: 0.560     Iterations: 56000
# 32  Nodes: 1600   Edges: 3200   phi: 0.780     Iterations: 24000
# 33  Nodes: 1600   Edges: 3200   phi: 0.780     Iterations: 80000
# 34  Nodes: 1600   Edges: 3200   phi: 0.120    Iterations: 168000
# 35  Nodes: 1600   Edges: 3200   phi: 0.120    Iterations: 200000
# 36  Nodes: 1600   Edges: 3200   phi: 0.560     Iterations: 40000
# 37  Nodes: 1600   Edges: 3200   phi: 0.560     Iterations: 40000
# 38  Nodes: 1600   Edges: 3200   phi: 0.890     Iterations: 24000
# 39  Nodes: 1600   Edges: 3200   phi: 0.890     Iterations: 24000
# 40  Nodes: 1600   Edges: 3200   phi: 0.230     Iterations: 88000
# 41  Nodes: 1600   Edges: 3200   phi: 0.340     Iterations: 56000
# 42  Nodes: 1600   Edges: 3200   phi: 0.340     Iterations: 56000
# 43  Nodes: 1600   Edges: 3200   phi: 0.340     Iterations: 56000
# 44  Nodes: 1600   Edges: 3200   phi: 0.450     Iterations: 56000
# 45  Nodes: 1600   Edges: 3200   phi: 0.450     Iterations: 48000
# 46  Nodes: 1600   Edges: 3200   phi: 0.780     Iterations: 32000
# 47  Nodes: 1600   Edges: 3200   phi: 0.780     Iterations: 24000
# 48  Nodes: 1600   Edges: 3200   phi: 1.000    Iterations: 280000
# 49  Nodes: 1600   Edges: 3200   phi: 1.000     Iterations: 48000
#
#                   4
# 0    Influencer: 2
# 1    Influencer: 4
# 2    Influencer: 0
# 3    Influencer: 2
# 4    Influencer: 4
# 5    Influencer: 6
# 6    Influencer: 8
# 7    Influencer: 0
# 8    Influencer: 4
# 9    Influencer: 6
# 10   Influencer: 8
# 11   Influencer: 0
# 12   Influencer: 0
# 13   Influencer: 2
# 14   Influencer: 0
# 15   Influencer: 2
# 16   Influencer: 8
# 17   Influencer: 0
# 18   Influencer: 8
# 19   Influencer: 0
# 20   Influencer: 2
# 21   Influencer: 4
# 22   Influencer: 0
# 23   Influencer: 2
# 24   Influencer: 4
# 25   Influencer: 6
# 26   Influencer: 4
# 27   Influencer: 6
# 28   Influencer: 6
# 29   Influencer: 8
# 30   Influencer: 2
# 31   Influencer: 4
# 32   Influencer: 6
# 33   Influencer: 8
# 34   Influencer: 6
# 35   Influencer: 8
# 36   Influencer: 6
# 37   Influencer: 8
# 38   Influencer: 0
# 39   Influencer: 2
# 40   Influencer: 8
# 41   Influencer: 0
# 42   Influencer: 2
# 43   Influencer: 4
# 44   Influencer: 4
# 45   Influencer: 6
# 46   Influencer: 2
# 47   Influencer: 4
# 48   Influencer: 6
# 49   Influencer: 8

# %% [markdown]
# Funktion die für gegebenes NNodes, NEdges, phi den Index im Datenframe (der Parameterwerte) ausgibt

# %%
import re

def getIndex(NNodes, NEdges, phi, kmanip):
    lines = []
    for j in range(frame.shape[0]): #all rows
        getstr = frame[0][j]
        if ([int(s) for s in getstr.split() if s.isdigit()][0] == NNodes):
            getstr = frame[1][j]
            if ([int(s) for s in getstr.split() if s.isdigit()][0] == NEdges):
                getstr = frame[2][j]
                if (float(re.findall("\d+\.\d+", getstr)[0]) == phi):
                    if manip != 1:
                        lines.append(j)
                    else:
                        getstr = frame[4][j]
                        if ([int(s) for s in getstr.split() if s.isdigit()][0] == kmanip):
                            lines.append(j)
    return lines

# %% [markdown]
# Funktion die für gegebenen Index des Dataframes (der Parameterwerte) den Meinungsvektor (OporComp = 0) oder den Komponentenvektor (OporComp = 1) oder den Influencervektor (OporComp = 2) aus der jeweiligen Datei liest

# %%
#OporComp = 0 for OpinionVector, 1 for ConnectedComponents
def getVector(frameIndex, OporComp):
    filename = (findfile[frameIndex])[0]
    fileindex = (findfile[frameIndex])[1]
    fileline = fileindex*(3+manip)+1
    OpinionVector = pd.read_csv(filename, skiprows = fileline+OporComp, nrows = 1, header=None, delim_whitespace = True)
    return OpinionVector

# %% [markdown]
# Funktion die für gegebenes NNodes, NEdges, phi einen Matplotlib subplot eines Plot der Größe x * y an index z erstellt

# %%
from collections import Counter
import matplotlib.pyplot as plt


#ComponentSizes dependent on Phi
def histogram( NNodes, phi, kinf):
    hist = [0] * (NNodes+1)
    lines = []
    lines = getIndex(NNodes, NNodes*2, phi, kinf)
    if (len(lines) == 0):
        print("No Dataset found for NNodes = %d, phi = %.3f" %(NNodes,  phi))
        return
    for i in range(len(lines)):
        compvec=[NNodes] #empty array
        compvec = getVector(lines[i],1) #getComponentsizevector
        compvec = compvec.values.tolist()[0] #get list from dataframe
        compdic = Counter(compvec) #get Dict of type (compent number) : size
        comps = list(compdic.values()) #get list of size values
        d = Counter(comps) #get Dict sizeofCompononent : appearance
        for siz, app in d.items():
            hist[siz] += app
        hist[:] = [float(x) / NNodes for x in hist]
    hist[:] = [float(x) / len(lines) for x in hist] #average over number of datasets
    #hist[:] = [float(x) / NNodes for x in hist] 
    #axs = axs.flatten()
    #axs[ithplot].loglog(hist, 'o')
    plt.loglog(hist, 'o')
    title = "Phi: " +str(float(phi)) + " averaged over " + str(len(lines))
    #axs[ithplot].set_title(title)
    #axs[ithplot].set_xlim(xmin=0, xmax=NNodes)
    #axs[ithplot].set_ylim(ymin = 0.00001, ymax=1.1)
    plt.title(title)
    plt.xlim(xmin=0, xmax=NNodes)
    plt(ylimymin = 0.00001, ymax = 1.1)
    plt.show()
    picfilename = input("Filename? 0 to cancel")
    if picfilename != '0':
        picfilename = "./hist/" +str(picfilename)
        fig.savefig(picfilename)

# %%
def WhichNNodes():
    Nodelist = []
    for j in range(frame.shape[0]):
        getstr = frame[0][j]
        newNode = [int(s) for s in getstr.split() if s.isdigit()][0]
        if newNode not in Nodelist:
            Nodelist.append(newNode)
    return Nodelist

def WhichPhi():
    philist = []
    for j in range(frame.shape[0]): #all rows
        getstr = frame[2][j]
        newphi = float(re.findall("\d+\.\d+", getstr)[0])
        if newphi not in philist:
            philist.append(newphi)
    return philist

def WhichKinf():
    KinfList = []
    for j in range(frame.shape[0]): #all rows
        getstr = frame[4][j]
        newkinf = [int(s) for s in getstr.split() if s.isdigit()][0]
        if newkinf not in KinfList:
            KinfList.append(newkinf)
    return KinfList

# %% [markdown]
# DomOp gets Values for NNodes and phi and returns the ratio of Opinion 0 Nodes and other Opinion nodes

# %%
def DomOp(NNodes, phi, kInf):
    Dom = 0.
    lines = []
    lines = getIndex(NNodes, NNodes*2, phi, kInf)
    
    if (len(lines) == 0):
        print("No Dataset found for %d, %d, %.3f, %d" %(NNodes, NNodes*2, phi, kInf)) 
        return -1
    
    for i in range(len(lines)):        
        #get opinion vector
        opvec = getVector(lines[i],0)
        
        #get list from dataframe
        opvec = opvec.values.tolist()[0]
        
        #get Dict of type (opinion number) : size
        opvec = Counter(opvec) 
        #print(opvec)
        #get Number of Nodes that have Opinion 0
        Curr_Dom = float(list(opvec.values())[0])
        #print(Curr_Dom)
        #divided by mean of all OTHER opinions
        Curr_Dom = Curr_Dom/(NNodes - Curr_Dom) * (NNodes/10 -1) 
        #print(Curr_Dom)
        #print(CurrInfOpDom)
        Dom += Curr_Dom
        
    Dom = Dom/(len(lines))
    return Dom

# %% [markdown]
# Gets NNodes value and InPhi, InNinf list and creates plot of OpDomination / Phi with a line for each element of InNinf

# %%
def Plot_DomPhi(NNodes, InPhi, InNinf):
    plotdata = [[0 for x in range(len(InPhi))] for y in range(len(InNinf))] 
    for i, Phi in enumerate(InPhi):
        for j, Inf in enumerate(InNinf):
            temp = DomOp(NNodes, Phi, Inf)
            if temp != -1:
                plotdata[i][j] = DomOp(NNodes, Phi, Inf)
        plt.scatter(InPhi, plotdata[i])
    plt.show()
    picfilename = input("Filename? 0 to cancel")
    if picfilename != '0':
        picfilename = "./DomPhi/" +str(picfilename)
        fig.savefig(picfilename) 
    return


def Plot_DomKinf(NNodes, InPhi, InNinf):
    plotdata = [[0 for x in range(len(InNinf))] for y in range(len(InPhi))] # plotdata[i][j] limited by i<len(InPhi) and j<len(InNinf)!!!!
    for i,Inf in enumerate(InNinf):
        for j,Phi in enumerate(InPhi):
            temp = DomOp(NNodes, Phi, Inf)
            if temp != -1:
                plotdata[j][i] = temp
            else:
                continue
    return plotdata
    #    plt.scatter(InNinf, plotdata[i])
    #plt.show()
    #picfilename = input("Filename? 0 to cancel")
    #if picfilename != '0':
    #    picfilename = "./DomKinf/" +str(picfilename)
    #    fig.savefig(picfilename) 

    
def Plot_DomKinf2(NNodes, InPhi, InNinf):
    plotdata = np.zeros((len(InPhi), len(InNinf)))
    # plotdata[i][j] limited by i<len(InPhi) and j<len(InNinf)!!!!
    for i,Inf in enumerate(InNinf):
        for j,Phi in enumerate(InPhi):
            temp = DomOp(NNodes, Phi, Inf)
            if temp != -1:
                plotdata[j][i] = temp
            else:
                continue
    return plotdata

# %%
getdata = Plot_DomKinf2(WhichNNodes()[0],WhichPhi(), WhichKinf() ) #getdata ist 2D Array InPhi x InNinf mit DomOp Werten

# %%
getdata_df = pd.DataFrame(data=getdata[0:,0:], index=WhichPhi(),columns=WhichKinf())
getdata_df.sort_index(inplace = True)
getdata_df.sort_index(axis = 1, inplace = True)
display(getdata_df)
# Out:
#              0          2         4          6         8
# 0.01  1.910816   7.165905  1.707517   2.114630  2.114630
# 0.12  3.868118   1.302457  7.601179   4.917526  3.452107
# 0.23  5.129032  43.225755  1.606061   5.023211  5.234990
# 0.34  3.141491   7.165905  1.100692   9.588469  1.910816
# 0.45  3.141491   4.076923  3.659847   3.244898  2.626429
# 0.56  0.498433   4.391137  5.234990   2.729180  5.023211
# 0.67  5.023211   2.626429  1.606061   8.258383  0.798995
# 0.78  1.504732   1.504732  1.809102  10.261477  2.318960
# 0.89  6.409623   2.832061  8.920792   1.100692  2.626429
# 1.00  1.910816   3.141491  1.000000   2.012658  3.555911

# %%
getdata_sorted = getdata_df.values.tolist()
xaxis =WhichKinf()
xaxis.sort()
labels = WhichPhi()
labels.sort()
for count, val in enumerate(getdata_sorted):
    labelstr = "phi " +str(labels[count])
    plt.plot(xaxis, val, label= labelstr)
plt.ylim(0,20)
plt.legend()
plt.show()

# %%
# Out:
# [2, 4, 0, 6, 8]

# %%
from tempfile import TemporaryFile
outfile = TemporaryFile()
np.save(outfile, getdata)

# %%
print(getdata)

# %%
x = WhichPhi()
y = WhichKinf()

xs, ys = np.meshgrid(x, y)
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(getdata, rstride=1, cstride=1, cmap='hot')
plt.show(
